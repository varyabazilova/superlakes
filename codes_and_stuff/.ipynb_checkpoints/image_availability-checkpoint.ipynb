# %%
#!/usr/bin/env python3
"""
Visualize image availability across time (2020-2024)
Shows timeline with monthly divisions and dots for available image dates
"""

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import glob
import os
import re
from datetime import datetime, timedelta
from pathlib import Path

def extract_dates_from_mosaics(base_dir):
    """
    Extract dates from all mosaic files across all years
    
    Returns:
    list: List of datetime objects for all available images
    """
    all_dates = []
    
    # Define year directories
    year_dirs = {
        2020: "langtang2020_harmonized_mosaics",
        2021: "langtang2021_harmonized_mosaics", 
        2022: "langtang2022_harmonized_mosaics",
        2023: "langtang2023_harmonized_mosaics",
        2024: "langtang2024_harmonized_mosaics"
    }
    
    for year, dir_name in year_dirs.items():
        year_path = os.path.join(base_dir, dir_name)
        
        if os.path.exists(year_path):
            # Find all mosaic files
            mosaic_files = glob.glob(os.path.join(year_path, "*_composite_mosaic.tif"))
            
            for file_path in mosaic_files:
                basename = os.path.basename(file_path)
                # Extract date pattern YYYY-MM-DD
                match = re.search(r'(\d{4}-\d{2}-\d{2})', basename)
                if match:
                    date_str = match.group(1)
                    try:
                        date_obj = datetime.strptime(date_str, '%Y-%m-%d')
                        all_dates.append(date_obj)
                        print(f"Found image: {date_str}")
                    except ValueError:
                        print(f"Could not parse date: {date_str}")
        else:
            print(f"Directory not found: {year_path}")
    
    return sorted(all_dates)

def create_availability_plot(dates, output_path=None):
    """
    Create timeline plot showing image availability
    
    Parameters:
    dates (list): List of datetime objects
    output_path (str): Optional path to save the plot
    """
    if not dates:
        print("No dates found to plot")
        return
    
    # Create figure
    fig, ax = plt.subplots(figsize=(16, 8))
    
    # Define time range (2020-2024)
    start_date = datetime(2020, 1, 1)
    end_date = datetime(2025, 1, 1)
    
    # Create monthly grid lines
    current = start_date
    month_starts = []
    while current < end_date:
        month_starts.append(current)
        # Move to next month
        if current.month == 12:
            current = current.replace(year=current.year + 1, month=1)
        else:
            current = current.replace(month=current.month + 1)
    
    # Plot vertical lines for each month
    for month_start in month_starts:
        ax.axvline(x=month_start, color='lightgray', linestyle='-', alpha=0.3, linewidth=0.5)
    
    # Plot dots for available images
    y_position = 1  # All dots on same horizontal line
    ax.scatter(dates, [y_position] * len(dates), 
              color='blue', s=60, alpha=0.8, zorder=3)
    
    # Customize plot
    ax.set_xlim(start_date, end_date)
    ax.set_ylim(0.5, 1.5)
    
    # Format x-axis
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    
    # Add monthly labels
    for i, month_start in enumerate(month_starts[::12]):  # Every 12 months (yearly)
        year = month_start.year
        # Add small monthly tick marks
        year_months = [d for d in month_starts if d.year == year]
        for j, month in enumerate(year_months):
            ax.axvline(x=month, color='gray', linestyle='-', alpha=0.5, linewidth=1)
            # Add month labels for better readability
            if j % 3 == 0:  # Every 3 months
                ax.text(month, 0.7, month.strftime('%b'), 
                       rotation=45, ha='right', va='top', fontsize=8, alpha=0.7)
    
    # Labels and title
    ax.set_xlabel('Time (2020-2024)', fontsize=12, fontweight='bold')
    ax.set_ylabel('')
    ax.set_title('Planet Imagery Availability Timeline - Langtang Glacial Lakes\n'
                'Blue dots indicate available mosaic images', 
                fontsize=14, fontweight='bold', pad=20)
    
    # Remove y-axis ticks and labels
    ax.set_yticks([])
    
    # Add grid
    ax.grid(True, axis='x', alpha=0.3)
    
    # Add statistics text
    stats_text = f"Total images: {len(dates)}\n"
    stats_text += f"Date range: {min(dates).strftime('%Y-%m-%d')} to {max(dates).strftime('%Y-%m-%d')}\n"
    
    # Count images by year
    year_counts = {}
    for date in dates:
        year = date.year
        year_counts[year] = year_counts.get(year, 0) + 1
    
    stats_text += "Images per year:\n"
    for year in sorted(year_counts.keys()):
        stats_text += f"  {year}: {year_counts[year]} images\n"
    
    ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, 
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
            verticalalignment='top', fontsize=10)
    
    # Tight layout
    plt.tight_layout()
    
    # Save or show
    if output_path:
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to: {output_path}")
    else:
        plt.show()
    
    return fig, ax

def main():
    """Main function"""
    print("Creating Planet imagery availability timeline...")
    print("=" * 60)
    
    # Configuration
    base_mosaic_dir = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/Images_mosaics"
    output_path = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png"
    
    # Extract dates
    print("Extracting dates from mosaic files...")
    dates = extract_dates_from_mosaics(base_mosaic_dir)
    
    print(f"\nFound {len(dates)} images total")
    print("Date range:", min(dates).strftime('%Y-%m-%d'), "to", max(dates).strftime('%Y-%m-%d'))
    
    # Create plot
    print("\nCreating timeline plot...")
    fig, ax = create_availability_plot(dates, output_path)
    
    print("\nTimeline visualization complete!")
    print(f"Output saved to: {output_path}")

if __name__ == "__main__":
    main()
# Out:
# Creating Planet imagery availability timeline...
# ============================================================
# Extracting dates from mosaic files...
# Found image: 2020-10-05
# Found image: 2020-09-30
# Found image: 2020-10-18
# Found image: 2020-10-01
# Found image: 2020-06-11
# Found image: 2020-10-13
# Found image: 2020-08-08
# Found image: 2020-05-24
# Found image: 2020-10-08
# Found image: 2020-10-07
# Found image: 2020-10-23
# Found image: 2020-08-31
# Found image: 2020-10-11
# Found image: 2020-09-21
# Found image: 2020-10-09
# Found image: 2021-10-13
# Found image: 2021-01-28
# Found image: 2021-03-17
# Found image: 2021-10-05
# Found image: 2021-03-03
# Found image: 2021-10-09
# Found image: 2021-02-24
# Found image: 2021-09-04
# Found image: 2021-09-18
# Found image: 2021-09-20
# Found image: 2021-10-15
# Found image: 2022-06-01
# Found image: 2022-10-03
# Found image: 2022-06-13
# Found image: 2022-04-07
# Found image: 2022-06-05
# Found image: 2022-07-16
# Found image: 2022-04-05
# Found image: 2022-06-11
# Found image: 2022-09-29
# Found image: 2022-04-12
# Found image: 2022-05-15
# Found image: 2022-09-22
# Found image: 2022-07-05
# Found image: 2022-04-24
# Found image: 2022-05-14
# Found image: 2022-04-13
# Found image: 2023-08-27
# Found image: 2023-09-17
# Found image: 2023-02-25
# Found image: 2023-06-05
# Found image: 2023-08-30
# Found image: 2023-06-21
# Found image: 2023-09-16
# Found image: 2023-06-01
# Found image: 2023-08-31
# Found image: 2023-09-02
# Found image: 2023-06-07
# Found image: 2023-06-02
# Found image: 2023-09-27
# Found image: 2023-06-06
# Found image: 2023-06-03
# Found image: 2023-06-09
# Found image: 2023-09-26
# Found image: 2023-06-11
# Found image: 2023-09-14
# Found image: 2023-05-30
# Found image: 2024-04-29
# Found image: 2024-06-05
# Found image: 2024-02-17
# Found image: 2024-04-26
# Found image: 2024-02-12
# Found image: 2024-08-15
# Found image: 2024-06-12
# Found image: 2024-04-28
# Found image: 2024-05-18
# Found image: 2024-07-29
# Found image: 2024-09-19
# Found image: 2024-04-30
# Found image: 2024-05-03
# Found image: 2024-06-15
# Found image: 2024-06-10
# Found image: 2024-05-11
# Found image: 2024-09-11
# Found image: 2024-06-11
# Found image: 2024-02-06
# Found image: 2024-08-16
# Found image: 2024-02-03
#
# Found 83 images total
# Date range: 2020-05-24 to 2024-09-19
#
# Creating timeline plot...
# Plot saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png
#
# Timeline visualization complete!
# Output saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png

# %%
#!/usr/bin/env python3
"""
Visualize image availability across time (2020-2024)
Shows timeline with monthly divisions and dots for available image dates
"""

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import glob
import os
import re
from datetime import datetime, timedelta
from pathlib import Path

def extract_dates_from_mosaics(base_dir):
    """
    Extract dates from all mosaic files across all years
    
    Returns:
    list: List of datetime objects for all available images
    """
    all_dates = []
    
    # Define year directories
    year_dirs = {
        2020: "langtang2020_harmonized_mosaics",
        2021: "langtang2021_harmonized_mosaics", 
        2022: "langtang2022_harmonized_mosaics",
        2023: "langtang2023_harmonized_mosaics",
        2024: "langtang2024_harmonized_mosaics"
    }
    
    for year, dir_name in year_dirs.items():
        year_path = os.path.join(base_dir, dir_name)
        
        if os.path.exists(year_path):
            # Find all mosaic files
            mosaic_files = glob.glob(os.path.join(year_path, "*_composite_mosaic.tif"))
            
            for file_path in mosaic_files:
                basename = os.path.basename(file_path)
                # Extract date pattern YYYY-MM-DD
                match = re.search(r'(\d{4}-\d{2}-\d{2})', basename)
                if match:
                    date_str = match.group(1)
                    try:
                        date_obj = datetime.strptime(date_str, '%Y-%m-%d')
                        all_dates.append(date_obj)
                        print(f"Found image: {date_str}")
                    except ValueError:
                        print(f"Could not parse date: {date_str}")
        else:
            print(f"Directory not found: {year_path}")
    
    return sorted(all_dates)

def create_availability_plot(dates, output_path=None):
    """
    Create timeline plot showing image availability with separate lines for each year
    
    Parameters:
    dates (list): List of datetime objects
    output_path (str): Optional path to save the plot
    """
    if not dates:
        print("No dates found to plot")
        return
    
    # Organize dates by year
    dates_by_year = {}
    for date in dates:
        year = date.year
        if year not in dates_by_year:
            dates_by_year[year] = []
        dates_by_year[year].append(date)
    
    # Create figure
    fig, ax = plt.subplots(figsize=(16, 10))
    
    # Define years and colors
    years = sorted(dates_by_year.keys())
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']  # Different colors for each year
    
    # Set up y-positions for each year (stacked vertically)
    y_positions = {year: i + 1 for i, year in enumerate(years)}
    
    # Create month grid for each year
    for i, year in enumerate(years):
        y_pos = y_positions[year]
        
        # Draw horizontal line for this year
        start_of_year = datetime(year, 1, 1)
        end_of_year = datetime(year, 12, 31)
        ax.plot([start_of_year, end_of_year], [y_pos, y_pos], 
                color='lightgray', linewidth=2, alpha=0.5, zorder=1)
        
        # Add monthly tick marks
        for month in range(1, 13):
            month_start = datetime(year, month, 1)
            ax.axvline(x=month_start, ymin=(y_pos-0.3)/(len(years)+1), ymax=(y_pos+0.3)/(len(years)+1), 
                      color='gray', linestyle='-', alpha=0.3, linewidth=0.5)
        
        # Plot dots for available images this year
        year_dates = dates_by_year[year]
        ax.scatter(year_dates, [y_pos] * len(year_dates), 
                  color=colors[i % len(colors)], s=80, alpha=0.8, zorder=3, 
                  label=f'{year} ({len(year_dates)} images)')
    
    # Set axis limits
    min_year = min(years)
    max_year = max(years)
    ax.set_xlim(datetime(min_year, 1, 1), datetime(max_year, 12, 31))
    ax.set_ylim(0.5, len(years) + 0.5)
    
    # Format x-axis
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))  # Every 3 months
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    
    # Set y-axis
    ax.set_yticks([y_positions[year] for year in years])
    ax.set_yticklabels([str(year) for year in years])
    ax.set_ylabel('Year', fontsize=12, fontweight='bold')
    
    # Labels and title
    ax.set_xlabel('Month', fontsize=12, fontweight='bold')
    ax.set_title('Planet Imagery Availability Timeline - Langtang Glacial Lakes\n'
                'Each line represents one year, dots show available images', 
                fontsize=14, fontweight='bold', pad=20)
    
    # Add grid
    ax.grid(True, axis='x', alpha=0.3)
    ax.grid(True, axis='y', alpha=0.2)
    
    # Add legend
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', frameon=True, 
              fancybox=True, shadow=True)
    
    # Add statistics text
    stats_text = f"Total images: {len(dates)}\n"
    stats_text += f"Date range: {min(dates).strftime('%Y-%m-%d')} to {max(dates).strftime('%Y-%m-%d')}\n\n"
    
    stats_text += "Images per year:\n"
    for year in years:
        count = len(dates_by_year[year])
        stats_text += f"  {year}: {count} images\n"
    
    ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, 
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
            verticalalignment='top', fontsize=10)
    
    # Tight layout
    plt.tight_layout()
    
    # Save or show
    if output_path:
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to: {output_path}")
    else:
        plt.show()
    
    return fig, ax

def main():
    """Main function"""
    print("Creating Planet imagery availability timeline...")
    print("=" * 60)
    
    # Configuration
    base_mosaic_dir = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/Images_mosaics"
    output_path = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png"
    
    # Extract dates
    print("Extracting dates from mosaic files...")
    dates = extract_dates_from_mosaics(base_mosaic_dir)
    
    print(f"\nFound {len(dates)} images total")
    print("Date range:", min(dates).strftime('%Y-%m-%d'), "to", max(dates).strftime('%Y-%m-%d'))
    
    # Create plot
    print("\nCreating timeline plot...")
    fig, ax = create_availability_plot(dates, output_path)
    
    print("\nTimeline visualization complete!")
    print(f"Output saved to: {output_path}")

if __name__ == "__main__":
    main()
# Out:
# Creating Planet imagery availability timeline...
# ============================================================
# Extracting dates from mosaic files...
# Found image: 2020-10-05
# Found image: 2020-09-30
# Found image: 2020-10-18
# Found image: 2020-10-01
# Found image: 2020-06-11
# Found image: 2020-10-13
# Found image: 2020-08-08
# Found image: 2020-05-24
# Found image: 2020-10-08
# Found image: 2020-10-07
# Found image: 2020-10-23
# Found image: 2020-08-31
# Found image: 2020-10-11
# Found image: 2020-09-21
# Found image: 2020-10-09
# Found image: 2021-10-13
# Found image: 2021-01-28
# Found image: 2021-03-17
# Found image: 2021-10-05
# Found image: 2021-03-03
# Found image: 2021-10-09
# Found image: 2021-02-24
# Found image: 2021-09-04
# Found image: 2021-09-18
# Found image: 2021-09-20
# Found image: 2021-10-15
# Found image: 2022-06-01
# Found image: 2022-10-03
# Found image: 2022-06-13
# Found image: 2022-04-07
# Found image: 2022-06-05
# Found image: 2022-07-16
# Found image: 2022-04-05
# Found image: 2022-06-11
# Found image: 2022-09-29
# Found image: 2022-04-12
# Found image: 2022-05-15
# Found image: 2022-09-22
# Found image: 2022-07-05
# Found image: 2022-04-24
# Found image: 2022-05-14
# Found image: 2022-04-13
# Found image: 2023-08-27
# Found image: 2023-09-17
# Found image: 2023-02-25
# Found image: 2023-06-05
# Found image: 2023-08-30
# Found image: 2023-06-21
# Found image: 2023-09-16
# Found image: 2023-06-01
# Found image: 2023-08-31
# Found image: 2023-09-02
# Found image: 2023-06-07
# Found image: 2023-06-02
# Found image: 2023-09-27
# Found image: 2023-06-06
# Found image: 2023-06-03
# Found image: 2023-06-09
# Found image: 2023-09-26
# Found image: 2023-06-11
# Found image: 2023-09-14
# Found image: 2023-05-30
# Found image: 2024-04-29
# Found image: 2024-06-05
# Found image: 2024-02-17
# Found image: 2024-04-26
# Found image: 2024-02-12
# Found image: 2024-08-15
# Found image: 2024-06-12
# Found image: 2024-04-28
# Found image: 2024-05-18
# Found image: 2024-07-29
# Found image: 2024-09-19
# Found image: 2024-04-30
# Found image: 2024-05-03
# Found image: 2024-06-15
# Found image: 2024-06-10
# Found image: 2024-05-11
# Found image: 2024-09-11
# Found image: 2024-06-11
# Found image: 2024-02-06
# Found image: 2024-08-16
# Found image: 2024-02-03
#
# Found 83 images total
# Date range: 2020-05-24 to 2024-09-19
#
# Creating timeline plot...
# Plot saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png
#
# Timeline visualization complete!
# Output saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png

# %%
#!/usr/bin/env python3
"""
Visualize image availability across time (2020-2024)
Shows timeline with monthly divisions and dots for available image dates
"""

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import glob
import os
import re
from datetime import datetime, timedelta
from pathlib import Path

def extract_dates_from_mosaics(base_dir):
    """
    Extract dates from all mosaic files across all years
    
    Returns:
    list: List of datetime objects for all available images
    """
    all_dates = []
    
    # Define year directories
    year_dirs = {
        2020: "langtang2020_harmonized_mosaics",
        2021: "langtang2021_harmonized_mosaics", 
        2022: "langtang2022_harmonized_mosaics",
        2023: "langtang2023_harmonized_mosaics",
        2024: "langtang2024_harmonized_mosaics"
    }
    
    for year, dir_name in year_dirs.items():
        year_path = os.path.join(base_dir, dir_name)
        
        if os.path.exists(year_path):
            # Find all mosaic files
            mosaic_files = glob.glob(os.path.join(year_path, "*_composite_mosaic.tif"))
            
            for file_path in mosaic_files:
                basename = os.path.basename(file_path)
                # Extract date pattern YYYY-MM-DD
                match = re.search(r'(\d{4}-\d{2}-\d{2})', basename)
                if match:
                    date_str = match.group(1)
                    try:
                        date_obj = datetime.strptime(date_str, '%Y-%m-%d')
                        all_dates.append(date_obj)
                        print(f"Found image: {date_str}")
                    except ValueError:
                        print(f"Could not parse date: {date_str}")
        else:
            print(f"Directory not found: {year_path}")
    
    return sorted(all_dates)

def create_availability_plot(dates, output_path=None):
    """
    Create timeline plot showing image availability with separate lines for each year
    
    Parameters:
    dates (list): List of datetime objects
    output_path (str): Optional path to save the plot
    """
    if not dates:
        print("No dates found to plot")
        return
    
    # Organize dates by year
    dates_by_year = {}
    for date in dates:
        year = date.year
        if year not in dates_by_year:
            dates_by_year[year] = []
        dates_by_year[year].append(date)
    
    # Create figure
    fig, ax = plt.subplots(figsize=(16, 8))
    
    # Define years and colors
    years = sorted(dates_by_year.keys())
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']  # Different colors for each year
    
    # Create monthly grid lines (vertical)
    for month in range(1, 13):
        month_date = datetime(2020, month, 1)  # Use 2020 as reference year
        ax.axvline(x=month_date, color='lightgray', linestyle='-', alpha=0.3, linewidth=0.5)
    
    # Plot dots for each year
    for i, year in enumerate(years):
        year_dates = dates_by_year[year]
        
        # Convert dates to month-day format (remove year component for x-axis)
        month_day_dates = []
        for date in year_dates:
            # Convert to same reference year (2020) to align on x-axis
            aligned_date = datetime(2020, date.month, date.day)
            month_day_dates.append(aligned_date)
        
        # Plot dots at year position on y-axis
        ax.scatter(month_day_dates, [year] * len(month_day_dates), 
                  color=colors[i % len(colors)], s=80, alpha=0.8, zorder=3, 
                  label=f'{year} ({len(year_dates)} images)')
    
    # Set axis limits
    ax.set_xlim(datetime(2020, 1, 1), datetime(2020, 12, 31))
    ax.set_ylim(min(years) - 0.5, max(years) + 0.5)
    
    # Format x-axis (months)
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    
    # Set y-axis (years)
    ax.set_yticks(years)
    ax.set_yticklabels([str(year) for year in years])
    ax.set_ylabel('Year', fontsize=12, fontweight='bold')
    
    # Labels and title
    ax.set_xlabel('Month', fontsize=12, fontweight='bold')
    ax.set_title('Planet Imagery Availability Timeline - Langtang Glacial Lakes\n'
                'Each row shows one year, dots show available images by month', 
                fontsize=14, fontweight='bold', pad=20)
    
    # Add grid
    ax.grid(True, axis='x', alpha=0.3)
    ax.grid(True, axis='y', alpha=0.2)
    
    # Add legend
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', frameon=True, 
              fancybox=True, shadow=True)
    
    # Add statistics text
    stats_text = f"Total images: {len(dates)}\n"
    stats_text += f"Date range: {min(dates).strftime('%Y-%m-%d')} to {max(dates).strftime('%Y-%m-%d')}\n\n"
    
    stats_text += "Images per year:\n"
    for year in years:
        count = len(dates_by_year[year])
        stats_text += f"  {year}: {count} images\n"
    
    ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, 
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
            verticalalignment='top', fontsize=10)
    
    # Tight layout
    plt.tight_layout()
    
    # Save or show
    if output_path:
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to: {output_path}")
    else:
        plt.show()
    
    return fig, ax

def main():
    """Main function"""
    print("Creating Planet imagery availability timeline...")
    print("=" * 60)
    
    # Configuration
    base_mosaic_dir = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/Images_mosaics"
    output_path = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png"
    
    # Extract dates
    print("Extracting dates from mosaic files...")
    dates = extract_dates_from_mosaics(base_mosaic_dir)
    
    print(f"\nFound {len(dates)} images total")
    print("Date range:", min(dates).strftime('%Y-%m-%d'), "to", max(dates).strftime('%Y-%m-%d'))
    
    # Create plot
    print("\nCreating timeline plot...")
    fig, ax = create_availability_plot(dates, output_path)
    
    print("\nTimeline visualization complete!")
    print(f"Output saved to: {output_path}")

if __name__ == "__main__":
    main()
# Out:
# Creating Planet imagery availability timeline...
# ============================================================
# Extracting dates from mosaic files...
# Found image: 2020-10-05
# Found image: 2020-09-30
# Found image: 2020-10-18
# Found image: 2020-10-01
# Found image: 2020-06-11
# Found image: 2020-10-13
# Found image: 2020-08-08
# Found image: 2020-05-24
# Found image: 2020-10-08
# Found image: 2020-10-07
# Found image: 2020-10-23
# Found image: 2020-08-31
# Found image: 2020-10-11
# Found image: 2020-09-21
# Found image: 2020-10-09
# Found image: 2021-10-13
# Found image: 2021-01-28
# Found image: 2021-03-17
# Found image: 2021-10-05
# Found image: 2021-03-03
# Found image: 2021-10-09
# Found image: 2021-02-24
# Found image: 2021-09-04
# Found image: 2021-09-18
# Found image: 2021-09-20
# Found image: 2021-10-15
# Found image: 2022-06-01
# Found image: 2022-10-03
# Found image: 2022-06-13
# Found image: 2022-04-07
# Found image: 2022-06-05
# Found image: 2022-07-16
# Found image: 2022-04-05
# Found image: 2022-06-11
# Found image: 2022-09-29
# Found image: 2022-04-12
# Found image: 2022-05-15
# Found image: 2022-09-22
# Found image: 2022-07-05
# Found image: 2022-04-24
# Found image: 2022-05-14
# Found image: 2022-04-13
# Found image: 2023-08-27
# Found image: 2023-09-17
# Found image: 2023-02-25
# Found image: 2023-06-05
# Found image: 2023-08-30
# Found image: 2023-06-21
# Found image: 2023-09-16
# Found image: 2023-06-01
# Found image: 2023-08-31
# Found image: 2023-09-02
# Found image: 2023-06-07
# Found image: 2023-06-02
# Found image: 2023-09-27
# Found image: 2023-06-06
# Found image: 2023-06-03
# Found image: 2023-06-09
# Found image: 2023-09-26
# Found image: 2023-06-11
# Found image: 2023-09-14
# Found image: 2023-05-30
# Found image: 2024-04-29
# Found image: 2024-06-05
# Found image: 2024-02-17
# Found image: 2024-04-26
# Found image: 2024-02-12
# Found image: 2024-08-15
# Found image: 2024-06-12
# Found image: 2024-04-28
# Found image: 2024-05-18
# Found image: 2024-07-29
# Found image: 2024-09-19
# Found image: 2024-04-30
# Found image: 2024-05-03
# Found image: 2024-06-15
# Found image: 2024-06-10
# Found image: 2024-05-11
# Found image: 2024-09-11
# Found image: 2024-06-11
# Found image: 2024-02-06
# Found image: 2024-08-16
# Found image: 2024-02-03
#
# Found 83 images total
# Date range: 2020-05-24 to 2024-09-19
#
# Creating timeline plot...
# Plot saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png
#
# Timeline visualization complete!
# Output saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png

# %%
#!/usr/bin/env python3
"""
Visualize image availability across time (2020-2024)
Shows timeline with monthly divisions and dots for available image dates
"""

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import glob
import os
import re
from datetime import datetime, timedelta
from pathlib import Path

def extract_dates_from_mosaics(base_dir):
    """
    Extract dates from all mosaic files across all years
    
    Returns:
    list: List of datetime objects for all available images
    """
    all_dates = []
    
    # Define year directories
    year_dirs = {
        2020: "langtang2020_harmonized_mosaics",
        2021: "langtang2021_harmonized_mosaics", 
        2022: "langtang2022_harmonized_mosaics",
        2023: "langtang2023_harmonized_mosaics",
        2024: "langtang2024_harmonized_mosaics"
    }
    
    for year, dir_name in year_dirs.items():
        year_path = os.path.join(base_dir, dir_name)
        
        if os.path.exists(year_path):
            # Find all mosaic files
            mosaic_files = glob.glob(os.path.join(year_path, "*_composite_mosaic.tif"))
            
            for file_path in mosaic_files:
                basename = os.path.basename(file_path)
                # Extract date pattern YYYY-MM-DD
                match = re.search(r'(\d{4}-\d{2}-\d{2})', basename)
                if match:
                    date_str = match.group(1)
                    try:
                        date_obj = datetime.strptime(date_str, '%Y-%m-%d')
                        all_dates.append(date_obj)
                        print(f"Found image: {date_str}")
                    except ValueError:
                        print(f"Could not parse date: {date_str}")
        else:
            print(f"Directory not found: {year_path}")
    
    return sorted(all_dates)

def create_availability_plot(dates, output_path=None):
    """
    Create timeline plot showing image availability with separate lines for each year
    
    Parameters:
    dates (list): List of datetime objects
    output_path (str): Optional path to save the plot
    """
    if not dates:
        print("No dates found to plot")
        return
    
    # Organize dates by year
    dates_by_year = {}
    for date in dates:
        year = date.year
        if year not in dates_by_year:
            dates_by_year[year] = []
        dates_by_year[year].append(date)
    
    # Create figure
    fig, ax = plt.subplots(figsize=(16, 8))
    
    # Define years and colors
    years = sorted(dates_by_year.keys())
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']  # Different colors for each year
    
    # Create monthly grid lines (vertical)
    for month in range(1, 13):
        month_date = datetime(2020, month, 1)  # Use 2020 as reference year
        ax.axvline(x=month_date, color='lightgray', linestyle='-', alpha=0.3, linewidth=0.5)
    
    # Plot dots for each year
    for i, year in enumerate(years):
        year_dates = dates_by_year[year]
        
        # Convert dates to month-day format (remove year component for x-axis)
        month_day_dates = []
        for date in year_dates:
            # Convert to same reference year (2020) to align on x-axis
            aligned_date = datetime(2020, date.month, date.day)
            month_day_dates.append(aligned_date)
        
        # Plot dots at year position on y-axis
        ax.scatter(month_day_dates, [year] * len(month_day_dates), 
                  color=colors[i % len(colors)], s=80, alpha=0.8, zorder=3, 
                  label=f'{year} ({len(year_dates)} images)')
    
    # Set axis limits
    ax.set_xlim(datetime(2020, 1, 1), datetime(2020, 12, 31))
    ax.set_ylim(min(years) - 0.5, max(years) + 0.5)
    
    # Format x-axis (months)
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    
    # Set y-axis (years)
    ax.set_yticks(years)
    ax.set_yticklabels([str(year) for year in years])
    ax.set_ylabel('Year', fontsize=12, fontweight='bold')
    
    # Labels and title
    ax.set_xlabel('Month', fontsize=12, fontweight='bold')
    ax.set_title('Planet Imagery Availability Timeline - Langtang Glacial Lakes\n'
                'Each row shows one year, dots show available images by month', 
                fontsize=14, fontweight='bold', pad=20)
    
    # Add grid
    ax.grid(True, axis='x', alpha=0.3)
    ax.grid(True, axis='y', alpha=0.2)
    
    # Add statistics text
    stats_text = f"Total images: {len(dates)}\n"
    stats_text += f"Date range: {min(dates).strftime('%Y-%m-%d')} to {max(dates).strftime('%Y-%m-%d')}\n\n"
    
    stats_text += "Images per year:\n"
    for year in years:
        count = len(dates_by_year[year])
        stats_text += f"  {year}: {count} images\n"
    
    ax.text(0.98, 0.98, stats_text, transform=ax.transAxes, 
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
            verticalalignment='top', horizontalalignment='right', fontsize=10)
    
    # Tight layout
    plt.tight_layout()
    
    # Save or show
    if output_path:
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to: {output_path}")
    else:
        plt.show()
    
    return fig, ax

def main():
    """Main function"""
    print("Creating Planet imagery availability timeline...")
    print("=" * 60)
    
    # Configuration
    base_mosaic_dir = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/Images_mosaics"
    output_path = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png"
    
    # Extract dates
    print("Extracting dates from mosaic files...")
    dates = extract_dates_from_mosaics(base_mosaic_dir)
    
    print(f"\nFound {len(dates)} images total")
    print("Date range:", min(dates).strftime('%Y-%m-%d'), "to", max(dates).strftime('%Y-%m-%d'))
    
    # Create plot
    print("\nCreating timeline plot...")
    fig, ax = create_availability_plot(dates, output_path)
    
    print("\nTimeline visualization complete!")
    print(f"Output saved to: {output_path}")

if __name__ == "__main__":
    main()
# Out:
# Creating Planet imagery availability timeline...
# ============================================================
# Extracting dates from mosaic files...
# Found image: 2020-10-05
# Found image: 2020-09-30
# Found image: 2020-10-18
# Found image: 2020-10-01
# Found image: 2020-06-11
# Found image: 2020-10-13
# Found image: 2020-08-08
# Found image: 2020-05-24
# Found image: 2020-10-08
# Found image: 2020-10-07
# Found image: 2020-10-23
# Found image: 2020-08-31
# Found image: 2020-10-11
# Found image: 2020-09-21
# Found image: 2020-10-09
# Found image: 2021-10-13
# Found image: 2021-01-28
# Found image: 2021-03-17
# Found image: 2021-10-05
# Found image: 2021-03-03
# Found image: 2021-10-09
# Found image: 2021-02-24
# Found image: 2021-09-04
# Found image: 2021-09-18
# Found image: 2021-09-20
# Found image: 2021-10-15
# Found image: 2022-06-01
# Found image: 2022-10-03
# Found image: 2022-06-13
# Found image: 2022-04-07
# Found image: 2022-06-05
# Found image: 2022-07-16
# Found image: 2022-04-05
# Found image: 2022-06-11
# Found image: 2022-09-29
# Found image: 2022-04-12
# Found image: 2022-05-15
# Found image: 2022-09-22
# Found image: 2022-07-05
# Found image: 2022-04-24
# Found image: 2022-05-14
# Found image: 2022-04-13
# Found image: 2023-08-27
# Found image: 2023-09-17
# Found image: 2023-02-25
# Found image: 2023-06-05
# Found image: 2023-08-30
# Found image: 2023-06-21
# Found image: 2023-09-16
# Found image: 2023-06-01
# Found image: 2023-08-31
# Found image: 2023-09-02
# Found image: 2023-06-07
# Found image: 2023-06-02
# Found image: 2023-09-27
# Found image: 2023-06-06
# Found image: 2023-06-03
# Found image: 2023-06-09
# Found image: 2023-09-26
# Found image: 2023-06-11
# Found image: 2023-09-14
# Found image: 2023-05-30
# Found image: 2024-04-29
# Found image: 2024-06-05
# Found image: 2024-02-17
# Found image: 2024-04-26
# Found image: 2024-02-12
# Found image: 2024-08-15
# Found image: 2024-06-12
# Found image: 2024-04-28
# Found image: 2024-05-18
# Found image: 2024-07-29
# Found image: 2024-09-19
# Found image: 2024-04-30
# Found image: 2024-05-03
# Found image: 2024-06-15
# Found image: 2024-06-10
# Found image: 2024-05-11
# Found image: 2024-09-11
# Found image: 2024-06-11
# Found image: 2024-02-06
# Found image: 2024-08-16
# Found image: 2024-02-03
#
# Found 83 images total
# Date range: 2020-05-24 to 2024-09-19
#
# Creating timeline plot...
# Plot saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png
#
# Timeline visualization complete!
# Output saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png

# %%
#!/usr/bin/env python3
"""
Visualize image availability across time (2020-2024)
Shows timeline with monthly divisions and dots for available image dates
"""

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import glob
import os
import re
from datetime import datetime, timedelta
from pathlib import Path

def extract_dates_from_mosaics(base_dir):
    """
    Extract dates from all mosaic files across all years
    
    Returns:
    list: List of datetime objects for all available images
    """
    all_dates = []
    
    # Define year directories
    year_dirs = {
        2020: "langtang2020_harmonized_mosaics",
        2021: "langtang2021_harmonized_mosaics", 
        2022: "langtang2022_harmonized_mosaics",
        2023: "langtang2023_harmonized_mosaics",
        2024: "langtang2024_harmonized_mosaics"
    }
    
    for year, dir_name in year_dirs.items():
        year_path = os.path.join(base_dir, dir_name)
        
        if os.path.exists(year_path):
            # Find all mosaic files
            mosaic_files = glob.glob(os.path.join(year_path, "*_composite_mosaic.tif"))
            
            for file_path in mosaic_files:
                basename = os.path.basename(file_path)
                # Extract date pattern YYYY-MM-DD
                match = re.search(r'(\d{4}-\d{2}-\d{2})', basename)
                if match:
                    date_str = match.group(1)
                    try:
                        date_obj = datetime.strptime(date_str, '%Y-%m-%d')
                        all_dates.append(date_obj)
                        print(f"Found image: {date_str}")
                    except ValueError:
                        print(f"Could not parse date: {date_str}")
        else:
            print(f"Directory not found: {year_path}")
    
    return sorted(all_dates)

def create_availability_plot(dates, output_path=None):
    """
    Create timeline plot showing image availability with separate lines for each year
    
    Parameters:
    dates (list): List of datetime objects
    output_path (str): Optional path to save the plot
    """
    if not dates:
        print("No dates found to plot")
        return
    
    # Organize dates by year
    dates_by_year = {}
    for date in dates:
        year = date.year
        if year not in dates_by_year:
            dates_by_year[year] = []
        dates_by_year[year].append(date)
    
    # Create figure
    fig, ax = plt.subplots(figsize=(16, 8))
    
    # Define years and colors
    years = sorted(dates_by_year.keys())
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']  # Different colors for each year
    
    # Create monthly and half-monthly grid lines (vertical)
    for month in range(1, 13):
        # First day of month (major grid line)
        month_date = datetime(2020, month, 1)
        ax.axvline(x=month_date, color='lightgray', linestyle='-', alpha=0.5, linewidth=1)
        
        # 15th of month (half-month grid line)
        half_month_date = datetime(2020, month, 15)
        ax.axvline(x=half_month_date, color='lightgray', linestyle='--', alpha=0.3, linewidth=0.5)
    
    # Plot dots for each year
    for i, year in enumerate(years):
        year_dates = dates_by_year[year]
        
        # Convert dates to month-day format (remove year component for x-axis)
        month_day_dates = []
        for date in year_dates:
            # Convert to same reference year (2020) to align on x-axis
            aligned_date = datetime(2020, date.month, date.day)
            month_day_dates.append(aligned_date)
        
        # Plot dots at year position on y-axis
        ax.scatter(month_day_dates, [year] * len(month_day_dates), 
                  facecolors='none', edgecolors=colors[i % len(colors)], 
                  s=120, alpha=0.8, linewidths=2, zorder=3, 
                  label=f'{year} ({len(year_dates)} images)')
    
    # Set axis limits
    ax.set_xlim(datetime(2020, 1, 1), datetime(2020, 12, 31))
    ax.set_ylim(min(years) - 0.5, max(years) + 0.5)
    
    # Format x-axis (months)
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    
    # Set y-axis (years)
    ax.set_yticks(years)
    ax.set_yticklabels([str(year) for year in years])
    ax.set_ylabel('Year', fontsize=12, fontweight='bold')
    
    # Labels and title
    ax.set_xlabel('Month', fontsize=12, fontweight='bold')
    ax.set_title('Planet Imagery Availability Timeline - Langtang Glacial Lakes\n'
                'Each row shows one year, dots show available images by month', 
                fontsize=14, fontweight='bold', pad=20)
    
    # Add grid
    ax.grid(True, axis='x', alpha=0.3)
    ax.grid(True, axis='y', alpha=0.2)
    
    # Add statistics text
    stats_text = f"Total images: {len(dates)}\n"
    stats_text += f"Date range: {min(dates).strftime('%Y-%m-%d')} to {max(dates).strftime('%Y-%m-%d')}\n\n"
    
    stats_text += "Images per year:\n"
    for year in years:
        count = len(dates_by_year[year])
        stats_text += f"  {year}: {count} images\n"
    
    ax.text(0.98, 0.98, stats_text, transform=ax.transAxes, 
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
            verticalalignment='top', horizontalalignment='right', fontsize=10)
    
    # Tight layout
    plt.tight_layout()
    
    # Save or show
    if output_path:
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to: {output_path}")
    else:
        plt.show()
    
    return fig, ax

def main():
    """Main function"""
    print("Creating Planet imagery availability timeline...")
    print("=" * 60)
    
    # Configuration
    base_mosaic_dir = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/Images_mosaics"
    output_path = "/Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png"
    
    # Extract dates
    print("Extracting dates from mosaic files...")
    dates = extract_dates_from_mosaics(base_mosaic_dir)
    
    print(f"\nFound {len(dates)} images total")
    print("Date range:", min(dates).strftime('%Y-%m-%d'), "to", max(dates).strftime('%Y-%m-%d'))
    
    # Create plot
    print("\nCreating timeline plot...")
    fig, ax = create_availability_plot(dates, output_path)
    
    print("\nTimeline visualization complete!")
    print(f"Output saved to: {output_path}")

if __name__ == "__main__":
    main()
# Out:
# Creating Planet imagery availability timeline...
# ============================================================
# Extracting dates from mosaic files...
# Found image: 2020-10-05
# Found image: 2020-09-30
# Found image: 2020-10-18
# Found image: 2020-10-01
# Found image: 2020-06-11
# Found image: 2020-10-13
# Found image: 2020-08-08
# Found image: 2020-05-24
# Found image: 2020-10-08
# Found image: 2020-10-07
# Found image: 2020-10-23
# Found image: 2020-08-31
# Found image: 2020-10-11
# Found image: 2020-09-21
# Found image: 2020-10-09
# Found image: 2021-10-13
# Found image: 2021-01-28
# Found image: 2021-03-17
# Found image: 2021-10-05
# Found image: 2021-03-03
# Found image: 2021-10-09
# Found image: 2021-02-24
# Found image: 2021-09-04
# Found image: 2021-09-18
# Found image: 2021-09-20
# Found image: 2021-10-15
# Found image: 2022-06-01
# Found image: 2022-10-03
# Found image: 2022-06-13
# Found image: 2022-04-07
# Found image: 2022-06-05
# Found image: 2022-07-16
# Found image: 2022-04-05
# Found image: 2022-06-11
# Found image: 2022-09-29
# Found image: 2022-04-12
# Found image: 2022-05-15
# Found image: 2022-09-22
# Found image: 2022-07-05
# Found image: 2022-04-24
# Found image: 2022-05-14
# Found image: 2022-04-13
# Found image: 2023-08-27
# Found image: 2023-09-17
# Found image: 2023-02-25
# Found image: 2023-06-05
# Found image: 2023-08-30
# Found image: 2023-06-21
# Found image: 2023-09-16
# Found image: 2023-06-01
# Found image: 2023-08-31
# Found image: 2023-09-02
# Found image: 2023-06-07
# Found image: 2023-06-02
# Found image: 2023-09-27
# Found image: 2023-06-06
# Found image: 2023-06-03
# Found image: 2023-06-09
# Found image: 2023-09-26
# Found image: 2023-06-11
# Found image: 2023-09-14
# Found image: 2023-05-30
# Found image: 2024-04-29
# Found image: 2024-06-05
# Found image: 2024-02-17
# Found image: 2024-04-26
# Found image: 2024-02-12
# Found image: 2024-08-15
# Found image: 2024-06-12
# Found image: 2024-04-28
# Found image: 2024-05-18
# Found image: 2024-07-29
# Found image: 2024-09-19
# Found image: 2024-04-30
# Found image: 2024-05-03
# Found image: 2024-06-15
# Found image: 2024-06-10
# Found image: 2024-05-11
# Found image: 2024-09-11
# Found image: 2024-06-11
# Found image: 2024-02-06
# Found image: 2024-08-16
# Found image: 2024-02-03
#
# Found 83 images total
# Date range: 2020-05-24 to 2024-09-19
#
# Creating timeline plot...
# Plot saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png
#
# Timeline visualization complete!
# Output saved to: /Users/varyabazilova/Desktop/glacial_lakes/super_lakes/codes_by_claude/imagery_availability_timeline.png
